# %%
# !pip install selenium

# %%
import selenium 
import pandas as pd 
from selenium import webdriver 
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time 
import requests
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
# Question 1

# %%
name = []
table_data = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[1]')
for tr in table_data:
    name.append(tr.text)

artist = []
table_data = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[2]')
for tr in table_data:
    artist.append(tr.text)    
views = []
table_data = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[3]')
for tr in table_data:
    views.append(tr.text) 
date = []
table_data = driver.find_elements(By.XPATH,'//table[@class="sortable wikitable sticky-header static-row-numbers col3center col4right jquery-tablesorter"]/tbody/tr/td[4]')
for tr in table_data:
    date.append(tr.text)

# %%
data = pd.DataFrame({"Name":name,"Artist":artist,"Views":views,"Upload_date":date})

# %%
data
# Out:
#                                                Name  \
# 0                             "Baby Shark Dance"[6]
# 1                                    "Despacito"[9]
# 2                        "Johny Johny Yes Papa"[17]
# 3                                   "Bath Song"[18]
# 4                                "Shape of You"[19]
# 5                               "See You Again"[22]
# 6                           "Wheels on the Bus"[27]
# 7                 "Phonics Song with Two Words"[28]
# 8                                 "Uptown Funk"[29]
# 9   "Learning Colors – Colorful Eggs on a Farm"[30]
# 10                              "Gangnam Style"[31]
# 11   "Masha and the Bear – Recipe for Disaster"[36]
# 12                             "Dame Tu Cosita"[37]
# 13                                     "Axel F"[38]
# 14                                      "Sugar"[39]
# 15                             "Counting Stars"[40]
# 16                                       "Roar"[41]
# ...

# %%
driver.quit()

# %%
# Question 2

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.bcci.tv/')

# %%
fixture = driver.find_element(By.XPATH,'/html/body/header/div[3]/div[2]/ul/div[1]/a[2]')
fixture.click()

# %%
series = []
place = []
date = []
time = []

series_data = driver.find_elements(By.XPATH,'//h5[@class="match-tournament-name ng-binding"]')
for i in series_data[1:8]:
    series.append(i.text)
    
place_data = driver.find_elements(By.XPATH,'//div[@class="match-place ng-scope"]')
for i in place_data:
    place.append(i.text)
    
date_data = driver.find_elements(By.XPATH,'//div[@class="match-dates ng-binding"]')
for i in date_data[1:8]:
    date.append(i.text)
    
time_data = driver.find_elements(By.XPATH,'//div[@class="match-time no-margin ng-binding"]')
for i in time_data[1:8]:
    time.append(i.text)

# %%
match = pd.DataFrame({"Series":series,"Place":place,"Date":date,"Time":time})

# %%
match
# Out:
#                                   Series                          Place  \
# 0  AUSTRALIA WOMEN TOUR OF INDIA 2023-24       Wankhede Stadium, Mumbai
# 1  AUSTRALIA WOMEN TOUR OF INDIA 2023-24       Wankhede Stadium, Mumbai
# 2  AUSTRALIA WOMEN TOUR OF INDIA 2023-24       Wankhede Stadium, Mumbai
# 3     INDIA TOUR OF SOUTH AFRICA 2023-24            Newlands, Cape Town
# 4  AUSTRALIA WOMEN TOUR OF INDIA 2023-24  DY Patil Stadium, NAVI MUMBAI
# 5  AUSTRALIA WOMEN TOUR OF INDIA 2023-24  DY Patil Stadium, NAVI MUMBAI
# 6  AUSTRALIA WOMEN TOUR OF INDIA 2023-24  DY Patil Stadium, NAVI MUMBAI
#
#                 Date         Time
# 0  28 DECEMBER, 2023  2:00 PM IST
# 1  30 DECEMBER, 2023  2:00 PM IST
# 2    2 JANUARY, 2024  2:00 PM IST
# 3    3 JANUARY, 2024  1:30 PM IST
# 4    5 JANUARY, 2024  7:00 PM IST
# 5    7 JANUARY, 2024  7:00 PM IST
# 6    9 JANUARY, 2024  7:00 PM IST

# %%
driver.quit()

# %%
# question 3

# %%
driver = webdriver.Chrome()

# %%
driver.get('http://statisticstimes.com/')

# %%
economy_button = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')
click_button = (economy_button.get_attribute('href'))

# %%
driver.get(click_button)

# %%
gdp = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]')
gdp.click()

# %%
rank = []
rank_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[1]')
for tr in rank_data:
    rank.append(tr.text)
    
state = []
state_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[2]')
for tr in state_data:
    state.append(tr.text)
    
gsdp22_23 = []
gsdp1_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[3]')
for tr in gsdp1_data:
    gsdp22_23.append(tr.text)
    
gsdp21_22 = []
gsdp2_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]')
for tr in gsdp2_data:
    gsdp21_22.append(tr.text)
    
share = []
share_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[4]')
for tr in share_data:
    share.append(tr.text)

gdp_total = []
gdp_data = driver.find_elements(By.XPATH,'//table[@class="display dataTable"]/tbody/tr/td[5]')
for tr in gdp_data:
    gdp_total.append(tr.text)
    
GDP_data = pd.DataFrame({"Rank":rank,"State":state,"GSDP2223":gsdp22_23,"GSDP2122":gsdp21_22,"share":share,"GDP":gdp_total})

# %%
GDP_data
# Out:
#    Rank                      State   GSDP2223   GSDP2122      share     GDP
# 0     1                Maharashtra          -  3,108,022  3,108,022  13.24%
# 1     2                 Tamil Nadu  2,364,514  2,071,286  2,071,286   8.82%
# 2     3              Uttar Pradesh  2,257,575  1,974,532  1,974,532   8.41%
# 3     4                  Karnataka  2,241,368  1,962,725  1,962,725   8.36%
# 4     5                    Gujarat          -  1,937,066  1,937,066   8.25%
# ..  ...                        ...        ...        ...        ...     ...
# 61   29          Arunachal Pradesh          -     31,669     31,669   0.16%
# 62   30                     Sikkim     35,670     31,519     31,519   0.16%
# 63   31                   Nagaland          -     27,859     27,859   0.14%
# 64   32                    Mizoram          -     24,293     24,293   0.12%
# 65   33  Andaman & Nicobar Islands          -      9,209      9,209   0.05%
#
# [66 rows x 6 columns]

# %%
driver.quit()

# %%
#Question 4

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://github.com/')

# %%
driver.get('https://github.com/trending')

# %%
title = []
title_data = driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')
for i in title_data:
    title.append(i.text)
    
description = []
desc_data = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in desc_data:
    description.append(i.text)

contributors_count = []
contr_data = driver.find_elements(By.XPATH,'//a[@class="Link Link--muted d-inline-block mr-3"][2]')
for i in contr_data:
    contributors_count.append(i.text)
    
language = []
lang_data = driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in lang_data:
    language.append(i.text)

# %%
print(title,description,contributors_count,language)
# Out:
# ['Frooodle / Stirling-PDF', 'BartoszJarocki / cv', 'nomic-ai / gpt4all', 'nodejs / undici', 'shadcn-ui / ui', 'apache / hudi', 'microsoft / promptbench', 'Hillobar / Rope', 'karanpratapsingh / system-design', 'DopplerHQ / awesome-interview-questions', 'movie-web / movie-web', 'HuolalaTech / page-spy-web', 'THUDM / ChatGLM3', 'd3george / slash-admin', 'iusztinpaul / hands-on-llms', 'cumulo-autumn / StreamDiffusion', 'xinghaochen / TinySAM', 'Flipper-XFW / Xtreme-Firmware', 'unocss / unocss', 'alibaba-damo-academy / FunASR', 'mouredev / roadmap-retos-programacion', 'ant-design / ant-design-web3', 'jqnatividad / qsv', 'nuxt / nuxt', 'baaivision / Emu'] ['locally hosted web application that allows you to perform various operations on PDF files', 'Print-friendly, minimalist CV page', 'gpt4all: open-source LLM chatbots that you can run anywhere', 'An HTTP/1.1 client, written from scratch for Node.js', 'Beautifully designed components that you can copy and paste into your apps. Accessible. 
# ...

# %%
# question 5

# %%
driver = webdriver.Chrome()

# %%
driver.get('https:/www.billboard.com/')

# %%
charts = driver.find_element(By.XPATH,'/html/body/div[3]/header/div/div[2]/div/div/div[2]/div[2]/div/div/nav/ul/li[1]/a')
charts.click()

# %%
charts1 = driver.find_element(By.XPATH,'/html/body/div[3]/main/div[2]/div[1]/div[1]/div/div/div[3]/a')
charts1.click()

# %%
name = []
name_data = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/h3')
for i in name_data:
    name.append(i.text)
    
artist = []
artist_data = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/span[1]')
for i in artist_data[::4]:
    artist.append(i.text)
    
lastweek = []
lastweek_data = driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]/span')
for i in lastweek_data[::2]:
    lastweek.append(i.text)
    
peak = []
peak_data = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/span[1]')
for i in peak_data[2::4]:
    peak.append(i.text)
    
weeks = []
weeks_data = driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]/ul/li/span[1]')
for i in weeks_data[3::4]:
    weeks.append(i.text)

# %%
chart_data = pd.DataFrame({"Name":name,"Artist":artist,"Lastweek":lastweek,"Peak":peak,"Weeks":weeks})

# %%
chart_data
# Out:
#                                  Name                                  Artist  \
# 0     All I Want For Christmas Is You                            Mariah Carey
# 1   Rockin' Around The Christmas Tree                              Brenda Lee
# 2                    Jingle Bell Rock                             Bobby Helms
# 3                      Last Christmas                                   Wham!
# 4             A Holly Jolly Christmas                               Burl Ives
# ..                                ...                                     ...
# 95                  Winter Wonderland                                   Chloe
# 96                  Run For The Hills                              Tate McRae
# 97                           Que Onda  Calle 24 x Chino Pacas x Fuerza Regida
# 98                       Great Gatsby                                Rod Wave
# 99                   One Of The Girls     The Weeknd, JENNIE & Lily Rose Depp
#
#    Lastweek Peak Weeks
# ...

# %%
# Question 6

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare')

# %%
name = []
name_data = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[2]')
for i in name_data:
    name.append(i.text)
    
author = []
author_data = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[3]')
for i in author_data:
    author.append(i.text)
    
volumes = []
volumes_data = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[4]')
for i in volumes_data:
    volumes.append(i.text)
    
publisher = []
publisher_data = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[5]')
for i in publisher_data:
    publisher.append(i.text)
    
genre = []
genre_data = driver.find_elements(By.XPATH,'//table[@class="in-article sortable"]/tbody/tr/td[6]')
for i in genre_data:
    genre.append(i.text)

# %%
books = pd.DataFrame({"Book Name":name,"Author":author,"Volumes sold":volumes,"Publisher":publisher,"Genre":genre})

# %%
books
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes sold        Publisher                        Genre
# ...

# %%
driver.quit()

# %%
# question 7

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://www.imdb.com/chart/tvmeter/?ref_=nv_tvv_mptv')

# %%
title = []
title_data = driver.find_elements(By.XPATH,'//h3[@class="ipc-title__text"]')
for i in title_data[1:101]:
    title.append(i.text)
    
year = []
year_data = driver.find_elements(By.XPATH,'//div[@class="sc-43986a27-7 dBkaPT cli-title-metadata"]/span')
for i in year_data[::3]:
    year.append(i.text)
    
genre_web = []
web_data = driver.find_elements(By.XPATH,'//span[@class="sc-43986a27-3 bQnSWs cli-title-type-data"]')
for i in web_data:
    genre_web.append(i.text)
    

    
rating = []
rating_data = driver.find_elements(By.XPATH,'//span[@class="sc-43986a27-1 fVmjht"]/div/span')
for i in rating_data:
    rating.append(i.text)

# %%
driver.quit()

# %%
# question 8

# %%
driver = webdriver.Chrome()

# %%
driver.get('https://archive.ics.uci.edu/')

# %%
dataset = driver.find_element(By.XPATH,'/html/body/div/div[1]/div[1]/main/div/div[1]/div/div/div/a[1]')
dataset.click()

# %%
start = 0
end = 10

# %%
name = []
name_dataset = driver.find_elements(By.XPATH,'//a[@class="link-hover link text-xl font-semibold"]')
for i in name_dataset:
    name.append(i.text)


type_data = []
typedata= driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]')
for i in typedata[1::4]:
    type_data.append(i.text)
    
data_task = []
task_dataset = driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"]')
for i in task_dataset[3::4]:
    data_task.append(i.text)
    
Attribute_type = []
attribute = driver.find_elements(By.XPATH,'//table[@class="col-span-full my-2 table sm:col-start-2"]')
for i in attribute:
    Attribute_type.append(i.text)

# %%
Attribute_type
# Out:
# ['Subject Area\nFeature Type\nDate Donated\nViews\nBiology Real 7/1/1988 568.42K']
